# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\aryan\OneDrive\\Documents\\DATA SCIENCE\\Machine Learning\\zML SELF PRACTICE\\GITREPO\\FT-PROJECTS\\5. Airline_Analysis\\Python_ML_Project_5_.csv')

# %%
data1 = data.copy(deep=True)
data2 = data.copy(deep=True)

# %%
data1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0             0           0   70172    Male     Loyal Customer   13
# 1             1           1    5047    Male  disloyal Customer   25
# 2             2           2  110028  Female     Loyal Customer   26
# 3             3           3   24026  Female     Loyal Customer   25
# 4             4           4  119299    Male     Loyal Customer   61
#
#     Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 0  Personal Travel  Eco Plus              460                      3  ...
# 1  Business travel  Business              235                      3  ...
# 2  Business travel  Business             1142                      2  ...
# 3  Business travel  Business              562                      2  ...
# 4  Business travel  Business              214                      3  ...
#
#    Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
data1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data1.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# ...

# %%
data1.drop('Unnamed: 0',axis=1)
# Out:
#       Unnamed: 0.1      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 9995          9995  124365    Male     Loyal Customer   50  Business travel
# 9996          9996   22044    Male     Loyal Customer   38  Business travel
# 9997          9997   14057  Female     Loyal Customer   39  Business travel
# 9998          9998  113848    Male     Loyal Customer   52  Business travel
# 9999          9999    1865  Female     Loyal Customer   41  Business travel
#
# ...

# %%
data1.columns=[each.replace(" ","_") for each in data1.columns]

# %%
data1
# Out:
#       Unnamed:_0.1  Unnamed:_0      id  Gender      Customer_Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type_of_Travel     Class  Flight_Distance  Inflight_wifi_service  ...  \
# ...

# %%
data1.columns
# Out:
# Index(['Unnamed:_0.1', 'Unnamed:_0', 'id', 'Gender', 'Customer_Type', 'Age',
#        'Type_of_Travel', 'Class', 'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data1['satisfaction'] = [1 if each=='satisfied' else 0 for each in data1.satisfaction]
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_3772\605484340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['satisfaction'] = [1 if each=='satisfied' else 0 for each in data1.satisfaction]

# %%
data1.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0.1  Unnamed: 0      id  Gender  Customer Type  Age  \
# 0                0           0   70172       1              0   13
# 1                1           1    5047       1              1   25
# 2                2           2  110028       0              0   26
# 3                3           3   24026       0              0   25
# 4                4           4  119299       1              0   61
# ...            ...         ...     ...     ...            ...  ...
# 9995          9995        9995  124365       1              0   50
# 9996          9996        9996   22044       1              0   38
# 9997          9997        9997   14057       0              0   39
# 9998          9998        9998  113848       1              0   52
# 9999          9999        9999    1865       0              0   41
#
#       Type of Travel  Class  Flight Distance  Inflight wifi service  ...  \
# ...

# %%
data1['satisfaction'].value_counts()
# Out:
# 0    5673
# 1    4301
# Name: satisfaction, dtype: int64

# %%
data1['satisfaction'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data1['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data1[["Gender","satisfaction"]].groupby(["Gender"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Gender  satisfaction
# 1       1      0.438294
# 0       0      0.424451

# %%
data1[["Age","satisfaction"]].groupby(["Age"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#     Age  satisfaction
# 71   79      0.666667
# 39   46      0.643192
# 34   41      0.632743
# 38   45      0.608466
# 66   73      0.600000
# ..  ...           ...
# 7    14      0.076923
# 0     7      0.071429
# 59   66      0.050000
# 69   76      0.000000
# 73   85      0.000000
#
# [74 rows x 2 columns]

# %%
data1[["Food and drink","satisfaction"]].groupby(["Food and drink"],as_index=False).mean().sort_values(by='satisfaction',ascending=False)
# Out:
#    Food and drink  satisfaction
# 0               0      0.625000
# 5               5      0.565959
# 4               4      0.515304
# 3               3      0.404613
# 2               2      0.363547
# 1               1      0.198296

# %%
data1['Flight_Distance'].plot(kind='box')
# Out:
# <Axes: >

# %%
data1.isnull().sum()
# Out:
# Unnamed:_0.1                          0
# Unnamed:_0                            0
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# ...

# %%
data1 = data.dropna()

# %%
data1.satisfaction
# Out:
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
#                  ...
# 9995                  satisfied
# 9996                  satisfied
# 9997                  satisfied
# 9998                  satisfied
# 9999                  satisfied
# Name: satisfaction, Length: 9974, dtype: object

# %%
data1.isnull().sum()
# Out:
# Unnamed: 0.1                         0
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# ...

# %%
data1['Flight Distance'].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443], dtype=int64)

# %% [markdown]
# # Part-2 Working with Models

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()

# %%
data1.loc[:, 'Gender'] = enc.fit_transform(data1["Gender"])
data1['Type of Travel'] = enc.fit_transform(data1['Type of Travel'])
data1['Type of Travel'] = enc.fit_transform(data1['Type of Travel'])
data1['Class'] = enc.fit_transform(data1['Class'])
data1['Customer Type'] = enc.fit_transform(data1['Customer Type'])
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_3772\2110556212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.loc[:, 'Gender'] = enc.fit_transform(data1["Gender"])
# C:\Users\aryan\AppData\Local\Temp\ipykernel_3772\2110556212.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data1.loc[:, 'Gender'] = enc.fit_transform(data1["Gender"])
# C:\Users\aryan\AppData\Local\Temp\ipykernel_3772\2110556212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data1
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender  Customer Type  Age  \
# 0                0           0   70172       1              0   13
# 1                1           1    5047       1              1   25
# 2                2           2  110028       0              0   26
# 3                3           3   24026       0              0   25
# 4                4           4  119299       1              0   61
# ...            ...         ...     ...     ...            ...  ...
# 9995          9995        9995  124365       1              0   50
# 9996          9996        9996   22044       1              0   38
# 9997          9997        9997   14057       0              0   39
# 9998          9998        9998  113848       1              0   52
# 9999          9999        9999    1865       0              0   41
#
#       Type of Travel  Class  Flight Distance  Inflight wifi service  ...  \
# 0                  1      2              460                      3  ...
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9974 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0.1                       9974 non-null   int64
#  1   Unnamed: 0                         9974 non-null   int64
#  2   id                                 9974 non-null   int64
#  3   Gender                             9974 non-null   int32
#  4   Customer Type                      9974 non-null   int32
#  5   Age                                9974 non-null   int64
#  6   Type of Travel                     9974 non-null   int64
#  7   Class                              9974 non-null   int32
#  8   Flight Distance                    9974 non-null   int64
#  9   Inflight wifi service              9974 non-null   int64
#  10  Departure/Arrival time convenient  9974 non-null   int64
# ...

# %%
x = data1.drop("satisfaction",axis=1)
y = data1['satisfaction']

# %%
x.shape
# Out:
# (9974, 25)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_scal = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scal,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (7979, 25)

# %%
x_test.shape
# Out:
# (1995, 25)

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score
model_dt.fit(x_train,y_train.ravel())
y_pred = model_dt.predict(x_test)
#print("pricison_score: ",precision_score(y_test, y_pred))
#print(confusion_matrix(y_test,y_pred))
#print(classification_report(y_test,y_pred,digits=5))

# %%
data1['satisfaction'] = [1 if each=='satisfied' else 0 for each in data1.satisfaction]
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_3772\605484340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['satisfaction'] = [1 if each=='satisfied' else 0 for each in data1.satisfaction]

# %%
print("pricison_score:  0.9384057971014492 \n recall_score:  0.9283154121863799 \n Accuracy = 0.9443609022556391")
# Out:
# pricison_score:  0.9384057971014492
#  recall_score:  0.9283154121863799
#  Accuracy = 0.9443609022556391
