# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('C:\\Users\\aryan\\OneDrive\\Documents\\DATA SCIENCE\\ML SELF PRACTICE\\GITREPO\\FT-PROJECTS\\3. Insurance_Data_Prediction\\Python_Linear_Regres.csv')

# %%
data1 = data.copy(deep=True)
data2 = data.copy(deep=True)

# %%
data1.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x='age', y='children', data=data1, hue='smoker')
# Out:
# <Axes: xlabel='age', ylabel='children'>

# %%
sns.barplot(x='children',y='bmi',data=data1, hue='smoker')
# Out:
# <Axes: xlabel='children', ylabel='bmi'>

# %%
data1 = pd.get_dummies(data1, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data1_scaled = pd.DataFrame(scaler.fit_transform(data1), columns=data1.columns)
data1_scaled.head()
# Out:
#         age       bmi  children   charges  sex_male  smoker_yes  \
# 0 -1.438764 -0.453320 -0.908614  0.298584 -1.010519    1.970587
# 1 -1.509965  0.509621 -0.078767 -0.953689  0.989591   -0.507463
# 2 -0.797954  0.383307  1.580926 -0.728675  0.989591   -0.507463
# 3 -0.441948 -1.305531 -0.908614  0.719843  0.989591   -0.507463
# 4 -0.513149 -0.292556 -0.908614 -0.776802  0.989591   -0.507463
#
#    region_northwest  region_southeast  region_southwest
# 0         -0.566418         -0.611324          1.765481
# 1         -0.566418          1.635795         -0.566418
# 2         -0.566418          1.635795         -0.566418
# 3          1.765481         -0.611324         -0.566418
# 4          1.765481         -0.611324         -0.566418

# %%
x = data1.drop('charges', axis=1)
y = data1['charges']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
mod = LinearRegression()
mod.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mod.predict(x_test)

# %%
sns.distplot((y_test-y_pred),bins=50)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 10756.946674467366

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 207685513.0142709

# %%
print(r2_score(y_test,y_pred))
# Out:
# -0.5993292815357865
